# %%
import pandas as pd
import numpy as np
import sklearn 
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('E:\\Data Trained\\Internship\\Micro-Credit-Project--3-\\Micro Credit Project\\Data file.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# There are 209593 rows and 37 columns

# %% [markdown]
# # Checking Null values in the dataframe

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# There is no null Values

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.loc[df['label']== " "]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, label, msisdn, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, pdate]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# # Visualization

# %%
ax = sn.countplot(x="label", data=df)
print(df["label"].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# There are 183431 label 1 and 26162 label 0

# %%
plt.figure(figsize=(20,7))
ax = sn.countplot(x="last_rech_amt_ma", data=df)
print(df["last_rech_amt_ma"].value_counts())
# Out:
# 1539     56297
# 770      41766
# 0        20995
# 773      19523
# 2309     16113
#          ...
# 34783        1
# 4066         1
# 772          1
# 19913        1
# 10454        1
# Name: last_rech_amt_ma, Length: 70, dtype: int64

# %% [markdown]
# Most of the customer's last recharge amount is rupees 1539

# %%
plt.figure(figsize=(20,7))
sn.countplot(df['cnt_ma_rech30'])
print(df["cnt_ma_rech30"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1      37238
# 2      31216
# 0      27979
# 3      25519
# 4      20258
#        ...
# 78         1
# 84         1
# 91         1
# 99         1
# 115        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['cnt_ma_rech90'])
print(df["cnt_ma_rech90"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1      27898
# 2      24052
# 0      20950
# 3      20446
# 4      17329
#        ...
# 336        1
# 151        1
# 132        1
# 140        1
# 127        1
# Name: cnt_ma_rech90, Length: 110, dtype: int64

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['fr_ma_rech90'])
print(df["fr_ma_rech90"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0     65753
# 1     24373
# 2     19285
# 3     13192
# 4     10021
#       ...
# 80        7
# 81        7
# 88        5
# 84        4
# 87        1
# Name: fr_ma_rech90, Length: 89, dtype: int64

# %%
plt.violinplot(df['sumamnt_ma_rech90'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x21c741a13a0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x21c741a1190>,
#  'cmins': <matplotlib.collections.LineCollection at 0x21c741a11f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x21c741a1850>}

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['cnt_da_rech90'])
print(df["cnt_da_rech90"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0     204226
# 1       4173
# 2        556
# 3        227
# 4        150
# 5         74
# 6         49
# 7         36
# 8         30
# 9         18
# 14        10
# 11         7
# 12         7
# 13         6
# 10         6
# 16         4
# 18         3
# 15         2
# 17         1
# 19         1
# 20         1
# 22         1
# 25         1
# 27         1
# 28         1
# 30         1
# 38         1
# Name: cnt_da_rech90, dtype: int64

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['fr_da_rech90'])
print(df["fr_da_rech90"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0     208728
# 3         78
# 1         66
# 2         66
# 4         56
# 7         55
# 6         52
# 5         45
# 8         44
# 10        33
# 9         32
# 14        32
# 11        30
# 12        27
# 19        22
# 28        19
# 13        17
# 15        17
# 18        16
# 29        15
# 17        14
# 16        14
# 22        11
# 25        11
# 21        10
# 20         9
# 24         8
# 27         8
# 32         8
# 26         7
# 30         7
# 31         6
# 34         5
# 37         5
# 23         5
# 57         3
# 35         2
# 41         2
# 33         1
# 39         1
# 42         1
# 43         1
# 46         1
# 55         1
# ...

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['cnt_loans30'])
print(df["cnt_loans30"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1     83432
# 2     42665
# 3     27050
# 4     17499
# 5     11673
# 6      7773
# 7      5041
# 8      3384
# 0      3259
# 9      2273
# 10     1571
# 11     1143
# 12      793
# 13      547
# 14      383
# 15      270
# 16      213
# 17      164
# 18       98
# 19       77
# 20       54
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 32        4
# 30        4
# 33        3
# 38        2
# 35        1
# 36        1
# 41        1
# 44        1
# 50        1
# Name: cnt_loans30, dtype: int64

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['amnt_loans30'])
print(df["amnt_loans30"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6      76620
# 12     44384
# 18     26379
# 24     18403
# 30     11999
# 36      8559
# 42      5580
# 48      3994
# 0       3259
# 54      2660
# 60      2043
# 66      1402
# 72      1101
# 78       742
# 84       580
# 90       394
# 96       333
# 102      252
# 108      182
# 114      135
# 120      119
# 132       92
# 126       80
# 138       64
# 156       34
# 150       30
# 144       30
# 162       29
# 168       20
# 174       17
# 186       15
# 180       13
# 192        7
# 198        6
# 210        4
# 216        4
# 228        4
# 252        4
# 222        3
# 258        3
# 264        3
# 276        3
# 204        2
# 240        2
# ...

# %%
plt.figure(figsize=(25,7))
sn.countplot(df['amnt_loans90'])
print(df["amnt_loans90"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 360        1
# 438        1
# 372        1
# 426        1
# 402        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %%
sn.countplot(df['maxamnt_loans90'])
print(df["maxamnt_loans90"].value_counts())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %%
sn.distplot(df['aon'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %%
sn.distplot(df['daily_decr30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
sn.distplot(df['daily_decr90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='daily_decr90', ylabel='Density'>

# %%
sn.distplot(df['rental30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rental30', ylabel='Density'>

# %%
sn.distplot(df['rental90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
sn.distplot(df['last_rech_date_ma'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %%
sn.distplot(df['last_rech_date_da'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='Density'>

# %%
sn.distplot(df['fr_ma_rech30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Density'>

# %%
sn.distplot(df['sumamnt_ma_rech30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='Density'>

# %%
sn.distplot(df['medianamnt_ma_rech30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='Density'>

# %%
sn.distplot(df['medianmarechprebal30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='Density'>

# %%
sn.distplot(df['medianamnt_ma_rech90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medianamnt_ma_rech90', ylabel='Density'>

# %%
sn.distplot(df['medianmarechprebal90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Density'>

# %%
sn.distplot(df['cnt_da_rech30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cnt_da_rech30', ylabel='Density'>

# %%
sn.distplot(df['fr_da_rech30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='Density'>

# %%
sn.distplot(df['maxamnt_loans30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Density'>

# %%
sn.distplot(df['medianamnt_loans30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Density'>

# %%
sn.distplot(df['cnt_loans90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Density'>

# %%
sn.distplot(df['medianamnt_loans90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medianamnt_loans90', ylabel='Density'>

# %%
sn.distplot(df['payback30'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='payback30', ylabel='Density'>

# %%
sn.distplot(df['payback90'], kde=True)
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='payback90', ylabel='Density'>

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=lb.fit_transform(df[i].values.reshape(-1,1))
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
df
# Out:
#         Unnamed: 0  label  msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0   40191   272.0   3055.050000   3065.150000
# 1                2      1  142291   712.0  12122.000000  12124.750000
# 2                3      1   33594   535.0   1398.000000   1398.000000
# 3                4      1  104157   241.0     21.228000     21.228000
# 4                5      1    6910   947.0    150.619333    150.619333
# ...            ...    ...     ...     ...           ...           ...
# 209588      209589      1   42866   404.0    151.872333    151.872333
# 209589      209590      1  178248  1075.0     36.936000     36.936000
# 209590      209591      1   53995  1013.0  11843.111667  11904.350000
# 209591      209592      1  111388  1732.0  12488.228333  12574.370000
# 209592      209593      1  121263  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# ...

# %% [markdown]
# # Describe Data

# %%
df.describe()
# Out:
#           Unnamed: 0          label         msisdn            aon  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177   93100.650179    8112.343445
# std     60504.431823       0.330519   53758.461427   75696.082531
# min         1.000000       0.000000       0.000000     -48.000000
# 25%     52399.000000       1.000000   46506.000000     246.000000
# 50%    104797.000000       1.000000   93073.000000     527.000000
# 75%    157195.000000       1.000000  139626.000000     982.000000
# max    209593.000000       1.000000  186242.000000  999860.755168
#
#         daily_decr30   daily_decr90       rental30       rental90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean     5381.402289    6082.515068    2692.581910    3483.406534
# std      9220.623400   10918.812767    4308.586781    5770.461279
# min       -93.012667     -93.012667  -23737.140000  -24720.580000
# ...

# %% [markdown]
# # Correlation with target columns

# %%
df.corr()
# Out:
#                       Unnamed: 0     label    msisdn       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403  0.000121 -0.002048      0.002739
# label                   0.000403  1.000000  0.001976 -0.003785      0.168298
# msisdn                  0.000121  0.001976  1.000000  0.000566      0.000717
# aon                    -0.002048 -0.003785  0.000566  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.000717  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000950  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.001404 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804 -0.002368  0.004256      0.275837
# ...

# %%
plt.figure(figsize=(22,7))
sn.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['label'].sort_values(ascending=False).drop(['label']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# No columns is highly correlated with target column

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    label  msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  104157  241.0     21.228000     21.228000    159.42    159.42
# 4      1    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %% [markdown]
# # Treating outtliers

# %%
plt.figure(figsize=(22,7))
df.plot(kind='box',subplots=True,layout=(6,6))
# Out:
# label                      AxesSubplot(0.125,0.772143;0.110714x0.107857)
# msisdn                  AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# aon                     AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# daily_decr30            AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# daily_decr90            AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# rental30                AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# rental90                   AxesSubplot(0.125,0.642714;0.110714x0.107857)
# last_rech_date_ma       AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# last_rech_date_da       AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# last_rech_amt_ma        AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# cnt_ma_rech30           AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# fr_ma_rech30            AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# sumamnt_ma_rech30          AxesSubplot(0.125,0.513286;0.110714x0.107857)
# ...

# %%
df.shape
# Out:
# (209593, 36)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64),
#  array([16, 16, 33, ..., 29, 27, 31], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
# Empty DataFrame
# Columns: [label, msisdn, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, pdate]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# # Spiliting target and features

# %%
x=df.iloc[:,1:36]
x.head()
# Out:
#    msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3  104157  241.0     21.228000     21.228000    159.42    159.42
# 4    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# 2                3.0                0.0              1539              1  ...
# 3               41.0                0.0               947              0  ...
# 4                4.0                0.0              2309              7  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
y=df.iloc[:,0]
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %% [markdown]
# # Balance the Target variable

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
x,y=smt.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    183431
# 1    183431
# Name: label, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[-0.98205185, -0.10482913, -0.07134939, ...,  2.5323811 ,
#          0.        ,  0.81215584],
#        [ 0.91517592, -0.09911094,  1.1348756 , ..., -0.37292819,
#          0.        ,  1.87908538],
#        [-1.10463767, -0.10141121, -0.29179564, ..., -0.37292819,
#          0.        ,  2.3363409 ],
#        ...,
#        [ 1.704746  , -0.10428935, -0.46469917, ...,  0.21707775,
#          0.        , -0.4071922 ],
#        [ 0.66331475, -0.10682703, -0.47468799, ..., -0.37292819,
#          0.        , -0.96606005],
#        [-0.37226315, -0.10165086, -0.09257457, ..., -0.37292819,
#          0.        ,  0.50731883]])

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
lg=LogisticRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lg.fit(x_train,y_train)
    pred_train=lg.predict(x_train)
    pred_test=lg.predict(x_test)
    print(f"At random state {i},the training accuracy is:- {accuracy_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {accuracy_score(y_test,pred_test)}")
    print("\n")
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# At random state 0,the training accuracy is:- 0.796489817335573
# At random state 0,the testing accuracy is:- 0.7958513349597264
# C:\Users\rupam\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=16)

# %%
x_train.shape
# Out:
# (245797, 35)

# %%
y_train.shape
# Out:
# (245797,)

# %%
x_test.shape
# Out:
# (121065, 35)

# %%
y_test.shape
# Out:
# (121065,)

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
pred=lg.predict(x_test)
print('Acuracy_score',accuracy_score(y_test,pred))
print('Confusion matrix',confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Acuracy_score 0.7957626068640813
# Confusion matrix [[51796  8638]
#  [16088 44543]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81     60434
#            1       0.84      0.73      0.78     60631
#
#     accuracy                           0.80    121065
#    macro avg       0.80      0.80      0.80    121065
# weighted avg       0.80      0.80      0.80    121065

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred=dt.predict(x_test)
print('Acuracy_score',accuracy_score(y_test,pred))
print('Confusion matrix',confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# Acuracy_score 0.9079750547226696
# Confusion matrix [[55115  5319]
#  [ 5822 54809]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91     60434
#            1       0.91      0.90      0.91     60631
#
#     accuracy                           0.91    121065
#    macro avg       0.91      0.91      0.91    121065
# weighted avg       0.91      0.91      0.91    121065

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('Acuracy_score',accuracy_score(y_test,pred))
print('Confusion matrix',confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# Acuracy_score 0.9447982488745715
# Confusion matrix [[56655  3779]
#  [ 2904 57727]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     60434
#            1       0.94      0.95      0.95     60631
#
#     accuracy                           0.94    121065
#    macro avg       0.94      0.94      0.94    121065
# weighted avg       0.94      0.94      0.94    121065

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lg,x,y,cv=5).mean())
# Out:
# C:\Users\rupam\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\rupam\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(cross_val_score(dt,x,y,cv=5).mean())
# Out:
# 0.9025330288521161

# %%
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# 0.9378024575768213

# %% [markdown]
# # AUC ROC Curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=rf.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([0.  , 0.77, 0.07, ..., 0.12, 0.96, 0.01])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.00000000e+00, 6.61879075e-05, 1.48922792e-04, 3.14392560e-04,
#        5.62597213e-04, 8.10801866e-04, 1.07555350e-03, 1.07555350e-03,
#        1.62160373e-03, 1.62160373e-03, 2.08491909e-03, 2.69715723e-03,
#        2.69715723e-03, 3.44177119e-03, 4.12019724e-03, 4.98064004e-03,
#        5.70870702e-03, 6.40368005e-03, 7.34685773e-03, 8.33967634e-03,
#        9.21666612e-03, 1.00274680e-02, 1.00274680e-02, 1.11857564e-02,
#        1.22613099e-02, 1.22613099e-02, 1.31217527e-02, 1.43462289e-02,
#        1.43462289e-02, 1.57030810e-02, 1.72584969e-02, 1.72584969e-02,
#        1.89793825e-02, 2.04189695e-02, 2.16434457e-02, 2.29672039e-02,
#        2.45060727e-02, 2.58298309e-02, 2.74183407e-02, 2.74183407e-02,
#        2.74183407e-02, 2.90068504e-02, 2.90068504e-02, 3.05622663e-02,
#        3.20184002e-02, 3.20349472e-02, 3.37723798e-02, 3.55925472e-02,
#        3.72803389e-02, 3.72803389e-02, 3.93321640e-02, 4.12019724e-02,
# ...

# %%
tpr
# Out:
# array([0.        , 0.20888654, 0.32244231, 0.40017483, 0.45785159,
#        0.50541802, 0.54557899, 0.54559549, 0.57970345, 0.57975293,
#        0.60911085, 0.63455988, 0.63457637, 0.65863997, 0.68034504,
#        0.69954314, 0.71753723, 0.73391499, 0.74879187, 0.7633059 ,
#        0.77651696, 0.78867246, 0.78868895, 0.79988785, 0.81032805,
#        0.81034454, 0.81977866, 0.82926226, 0.82927875, 0.83826755,
#        0.84629975, 0.84633273, 0.85408454, 0.86139104, 0.86775742,
#        0.87399185, 0.87961604, 0.88525672, 0.89056753, 0.89060052,
#        0.89061701, 0.89576289, 0.89577939, 0.90046346, 0.90486715,
#        0.90486715, 0.9091224 , 0.91344362, 0.91735251, 0.917369  ,
#        0.9207831 , 0.92437862, 0.92439511, 0.92736389, 0.93051409,
#        0.93348287, 0.93597335, 0.93598984, 0.93864525, 0.93869473,
#        0.93869473, 0.94121819, 0.94372516, 0.94606719, 0.94816183,
#        0.95033894, 0.95033894, 0.95210371, 0.95404991, 0.9555343 ,
# ...

# %%
thresholds
# Out:
# array([2.00000000e+00, 1.00000000e+00, 9.90000000e-01, 9.80000000e-01,
#        9.70000000e-01, 9.60000000e-01, 9.50000000e-01, 9.43333333e-01,
#        9.40000000e-01, 9.33333333e-01, 9.30000000e-01, 9.20000000e-01,
#        9.13000000e-01, 9.10000000e-01, 9.00000000e-01, 8.90000000e-01,
#        8.80000000e-01, 8.70000000e-01, 8.60000000e-01, 8.50000000e-01,
#        8.40000000e-01, 8.30000000e-01, 8.22500000e-01, 8.20000000e-01,
#        8.10000000e-01, 8.08000000e-01, 8.00000000e-01, 7.90000000e-01,
#        7.88000000e-01, 7.80000000e-01, 7.70000000e-01, 7.68000000e-01,
#        7.60000000e-01, 7.50000000e-01, 7.40000000e-01, 7.30000000e-01,
#        7.20000000e-01, 7.10000000e-01, 7.00000000e-01, 6.95000000e-01,
#        6.93333333e-01, 6.90000000e-01, 6.84761905e-01, 6.80000000e-01,
#        6.70000000e-01, 6.64761905e-01, 6.60000000e-01, 6.50000000e-01,
#        6.40000000e-01, 6.35000000e-01, 6.30000000e-01, 6.20000000e-01,
# ...

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random Forest')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Random Forest')
plt.show()

# %%
auc_score=roc_auc_score(y_test,rf.predict(x_test))

# %%
auc_score
# Out:
# 0.9447863418709935

# %% [markdown]
# # Hyper Parameter Tuning

# %%
parameter = {'n_estimators':[100,200, 400, 600, 800, 1000],'max_depth': [10, 20, 30],'min_samples_split': [2, 5, 10],'min_samples_leaf': [3, 4, 5,6],'max_features':['auto', 'sqrt']}

# %%
from sklearn.model_selection import GridSearchCV
GV=GridSearchCV(rf,parameter,cv=5)

# %%
GV.fit(x_train,y_train)

# %%
GV.best_params_

# %%
rf=RandomForestClassifier(n_estimators=600,max_depth=30,criterion='gini',min_samples_split=10,min_samples_leaf=5,max_features='auto')
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('Acuracy_score',accuracy_score(y_test,pred))
print(classification_report(y_test,pred))

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = 'Loan_Prediction.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('Loan_Prediction.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
